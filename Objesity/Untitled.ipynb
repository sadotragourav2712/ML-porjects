# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("obesity new.csv")
df.head()
# Out:
#    Gender Age  family_history_with_overweight  FAVC FCVC NCP  CAEC  SMOKE  \
# 0       0  21                               1     0    2   3     1      0
# 1       0  21                               1     0    3   3     1      1
# 2       1  23                               1     0    2   3     1      0
# 3       1  27                               0     0    3   3     1      0
# 4       1  22                               0     0    2   1     1      0
#
#   CH2O  SCC FAF TUE  CALC  Automobile  Bike  Motorbike  Public_Transportation  \
# 0    2    0   0   1     0           0     0          0                      1
# 1    3    1   3   0     1           0     0          0                      1
# 2    2    0   2   1     2           0     0          0                      1
# 3    2    0   2   0     2           0     0          0                      0
# 4    2    0   0   0     1           0     0          0                      1
#
#    Walking  NObeyesdad
# 0        0           0
# ...

# %%
category=['Male','Female']
plt.bar(category,df['Gender'].value_counts())
plt.show()

# %%
missing_data=df.isnull()

# %%
missing_data
# Out:
#       Gender    Age  family_history_with_overweight   FAVC   FCVC    NCP  \
# 0      False  False                           False  False  False  False
# 1      False  False                           False  False  False  False
# 2      False  False                           False  False  False  False
# 3      False  False                           False  False  False  False
# 4      False  False                           False  False  False  False
# ...      ...    ...                             ...    ...    ...    ...
# 2106   False  False                           False  False  False  False
# 2107   False  False                           False  False  False  False
# 2108   False  False                           False  False  False  False
# 2109   False  False                           False  False  False  False
# 2110   False  False                           False  False  False  False
#
#        CAEC  SMOKE   CH2O    SCC    FAF    TUE   CALC  Automobile   Bike  \
# ...

# %%
for c in missing_data.columns.values.tolist():
    print(c)
    print(missing_data[c].value_counts())
    print("")
# Out:
# Gender
# Gender
# False    2111
# Name: count, dtype: int64
#
# Age
# Age
# False    2111
# Name: count, dtype: int64
#
# family_history_with_overweight
# family_history_with_overweight
# False    2111
# Name: count, dtype: int64
#
# FAVC
# FAVC
# False    2111
# Name: count, dtype: int64
#
# FCVC
# FCVC
# False    2111
# Name: count, dtype: int64
#
# NCP
# NCP
# False    2111
# Name: count, dtype: int64
#
# CAEC
# CAEC
# False    2111
# Name: count, dtype: int64
#
# SMOKE
# SMOKE
# False    2111
# Name: count, dtype: int64
#
# CH2O
# CH2O
# False    2111
# Name: count, dtype: int64
#
# SCC
# SCC
# False    2111
# Name: count, dtype: int64
#
# FAF
# FAF
# False    2111
# Name: count, dtype: int64
#
# TUE
# TUE
# False    2111
# Name: count, dtype: int64
#
# CALC
# CALC
# False    2111
# Name: count, dtype: int64
#
# Automobile
# Automobile
# False    2111
# Name: count, dtype: int64
#
# Bike
# Bike
# False    2111
# Name: count, dtype: int64
#
# Motorbike
# Motorbike
# False    2111
# ...

# %%
#it has no null values

# %%
df.head()
# Out:
#    Gender Age  family_history_with_overweight  FAVC FCVC NCP  CAEC  SMOKE  \
# 0       0  21                               1     0    2   3     1      0
# 1       0  21                               1     0    3   3     1      1
# 2       1  23                               1     0    2   3     1      0
# 3       1  27                               0     0    3   3     1      0
# 4       1  22                               0     0    2   1     1      0
#
#   CH2O  SCC FAF TUE  CALC  Automobile  Bike  Motorbike  Public_Transportation  \
# 0    2    0   0   1     0           0     0          0                      1
# 1    3    1   3   0     1           0     0          0                      1
# 2    2    0   2   1     2           0     0          0                      1
# 3    2    0   2   0     2           0     0          0                      0
# 4    2    0   0   0     1           0     0          0                      1
#
#    Walking  NObeyesdad
# 0        0           0
# ...

# %%
plt.bar(df['Gender'],df['SMOKE'])
plt.show()
